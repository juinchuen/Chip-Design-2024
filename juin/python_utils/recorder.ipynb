# %%
import sounddevice as sd
import wavio as wv

import matplotlib.pyplot as plt
import matplotlib as mpl

import numpy as np

import serial

from fft_audio import fft_audio

# %%
sys = fft_audio()

sys.record_audio()
# Out:
# Say something!

# %%
sys.fpga_fft()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 sys.fpga_fft()
#
# File ~\Desktop\northwestern tings\Chip-Design-2024\juin\python_utils\fft_audio.py:97, in fft_audio.fpga_fft(self)
#      93 for i in range(int(len(bytes)/2)):
#      95     raw.append(int(bytes[2*i] * 256 + bytes[2*i+1]))
# ---> 97 real = np.array(raw[:64]).astype(np.float)
#      98 imag = np.array(raw[64:]).astype(np.float)
#     100 abs = np.sqrt(np.multiply(real, real) + np.multiply(imag, imag))
#
# File ~\anaconda3\lib\site-packages\numpy\__init__.py:305, in __getattr__(attr)
#     300     warnings.warn(
#     301         f"In the future `np.{attr}` will be defined as the "
#     302         "corresponding NumPy scalar.", FutureWarning, stacklevel=2)
#     304 if attr in __former_attrs__:
# --> 305     raise AttributeError(__former_attrs__[attr])
#     307 # Importing Tester requires importing all of UnitTest which is not a
#     308 # cheap import Since it is mainly used in test suits, we lazy import it
#     309 # here to save on the order of 10 ms of import time for most users
#     310 #
#     311 # The previous way Tester was imported also had a side effect of adding
#     312 # the full `numpy.testing` namespace
#     313 if attr == 'testing':
#
# AttributeError: module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
freq = 1000
duration = 5

sig = sd.rec(int(duration * freq), samplerate = freq, channels = 1, device=2)

sd.wait()

sig = sig.flatten()

# %%
sd.play(sig, freq)

# %%
windlist = []

index = 0
width = 64
half = 32
max_bits = 12

sig = sig - np.min(sig)
sig = sig / np.max(sig)
sig = 2 * sig - 1
sig = sig * 2 ** max_bits

while (index + width + 1 < len(sig)):

    windlist.append(sig[index : index + width])

    index = index + half

# %%
spectrogram = []

index = 0

width = 64

half = int(width/2)

while (index + width < len(sig)):

    # spectrogram.append(np.log(np.fft.fft(sig[index:index+width])[half:]))

    spectrogram.append(np.fft.fft(sig[index:index+width])[half:])

    # plt.plot(np.fft.fft(sig[index:index+width]))

    index = index + half

spectrogram = np.array(spectrogram)

spectrogram = np.absolute(spectrogram)

spectrogram = spectrogram - np.min(spectrogram)

spectrogram = spectrogram / np.max(spectrogram)

spectrogram = spectrogram * 255

# %%
# plt.figure(figsize=(10,10))
plt.imshow(spectrogram.transpose(), cmap='gray', vmin = 0, vmax=255, interpolation='nearest', aspect=2)

# %%
rec_fft = np.fft.fft(recording.flatten())

# %%
plt.plot(rec_fft.imag)

# %%
t = np.arange(256)
sp = np.fft.fft(np.sin(t) + np.sin(2 * t))
freq = np.fft.fftfreq(len(t))
plt.plot(freq, sp.real, freq, sp.imag)
plt.show()

# %%
sd.query_devices()
# Out:
#    0 Microsoft Sound Mapper - Input, MME (2 in, 0 out)
# >  1 Headset Microphone (Oculus Virt, MME (2 in, 0 out)
#    2 Headset (LE_WH-CH700N), MME (2 in, 0 out)
#    3 Microphone (DroidCam Virtual Au, MME (2 in, 0 out)
#    4 Microphone Array (Realtek(R) Au, MME (2 in, 0 out)
#    5 AI Noise-cancelling Input (ASUS, MME (2 in, 0 out)
#    6 Microsoft Sound Mapper - Output, MME (0 in, 2 out)
# <  7 Headphones (LE_WH-CH700N), MME (0 in, 2 out)
#    8 Speakers (Realtek(R) Audio), MME (0 in, 2 out)
#    9 1 - G34WQC A (AMD High Definiti, MME (0 in, 2 out)
#   10 Headphones (Oculus Virtual Audi, MME (0 in, 2 out)
#   11 AI Noise-cancelling Output (ASU, MME (0 in, 2 out)
#   12 Primary Sound Capture Driver, Windows DirectSound (2 in, 0 out)
#   13 Headset Microphone (Oculus Virtual Audio Device), Windows DirectSound (2 in, 0 out)
#   14 Headset (LE_WH-CH700N), Windows DirectSound (2 in, 0 out)
#   15 Microphone (DroidCam Virtual Audio), Windows DirectSound (2 in, 0 out)
#   16 Microphone Array (Realtek(R) Audio), Windows DirectSound (2 in, 0 out)
#   17 AI Noise-cancelling Input (ASUS Utility), Windows DirectSound (2 in, 0 out)
#   18 Primary Sound Driver, Windows DirectSound (0 in, 2 out)
#   19 Headphones (LE_WH-CH700N), Windows DirectSound (0 in, 2 out)
#   20 Speakers (Realtek(R) Audio), Windows DirectSound (0 in, 2 out)
#   21 1 - G34WQC A (AMD High Definition Audio Device), Windows DirectSound (0 in, 2 out)
#   22 Headphones (Oculus Virtual Audio Device), Windows DirectSound (0 in, 2 out)
#   23 AI Noise-cancelling Output (ASUS Utility), Windows DirectSound (0 in, 2 out)
#   24 Realtek ASIO, ASIO (2 in, 2 out)
#   25 Speakers (Realtek(R) Audio), Windows WASAPI (0 in, 2 out)
#   26 1 - G34WQC A (AMD High Definition Audio Device), Windows WASAPI (0 in, 2 out)
#   27 Headphones (Oculus Virtual Audio Device), Windows WASAPI (0 in, 2 out)
#   28 Headphones (LE_WH-CH700N), Windows WASAPI (0 in, 2 out)
#   29 AI Noise-cancelling Output (ASUS Utility), Windows WASAPI (0 in, 2 out)
#   30 Headset (LE_WH-CH700N), Windows WASAPI (1 in, 0 out)
#   31 Microphone (DroidCam Virtual Audio), Windows WASAPI (1 in, 0 out)
#   32 Headset Microphone (Oculus Virtual Audio Device), Windows WASAPI (1 in, 0 out)
#   33 Microphone Array (Realtek(R) Audio), Windows WASAPI (4 in, 0 out)
#   34 AI Noise-cancelling Input (ASUS Utility), Windows WASAPI (2 in, 0 out)
#   35 Microphone (Realtek HD Audio Mic input), Windows WDM-KS (2 in, 0 out)
#   36 Headphones (Realtek HD Audio 2nd output), Windows WDM-KS (0 in, 2 out)
#   37 Microphone Array (Realtek HD Audio Mic Array input), Windows WDM-KS (4 in, 0 out)
#   38 Speakers 1 (Realtek HD Audio output with HAP), Windows WDM-KS (0 in, 2 out)
#   39 Speakers 2 (Realtek HD Audio output with HAP), Windows WDM-KS (0 in, 2 out)
#   40 PC Speaker (Realtek HD Audio output with HAP), Windows WDM-KS (2 in, 0 out)
#   41 Headphones (), Windows WDM-KS (0 in, 2 out)
#   42 Headphones (), Windows WDM-KS (0 in, 2 out)
#   43 Output (@System32\drivers\bthhfenum.sys,#4;%1 Hands-Free HF Audio%0
# ;(Oh's Galaxy Tab S6 Lite)), Windows WDM-KS (0 in, 1 out)
#   44 Input (@System32\drivers\bthhfenum.sys,#4;%1 Hands-Free HF Audio%0
# ;(Oh's Galaxy Tab S6 Lite)), Windows WDM-KS (1 in, 0 out)
#   45 MIDI (DroidCam Audio), Windows WDM-KS (1 in, 0 out)
#   46 Output (DroidCam Audio), Windows WDM-KS (0 in, 1 out)
#   47 Input (), Windows WDM-KS (2 in, 0 out)
#   48 Output (AMD HD Audio HDMI out #0), Windows WDM-KS (0 in, 8 out)
#   49 Headset Microphone (OCULUSVAD Wave Microphone Headphone), Windows WDM-KS (1 in, 0 out)
#   50 Output 1 (OCULUSVAD Wave Speaker Headphone), Windows WDM-KS (0 in, 2 out)
#   51 Output 2 (OCULUSVAD Wave Speaker Headphone), Windows WDM-KS (0 in, 2 out)
#   52 Input (OCULUSVAD Wave Speaker Headphone), Windows WDM-KS (2 in, 0 out)
#   53 Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(TAOTRONICS SoundLiberty 79)), Windows WDM-KS (0 in, 1 out)
#   54 Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(TAOTRONICS SoundLiberty 79)), Windows WDM-KS (1 in, 0 out)
#   55 Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(UE BOOM1)), Windows WDM-KS (0 in, 1 out)
#   56 Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(UE BOOM1)), Windows WDM-KS (1 in, 0 out)
#   57 AI Noise-cancelling Input (Intelligo VAC (W)), Windows WDM-KS (2 in, 0 out)
#   58 Line Out 1 (Intelligo VAC (W)), Windows WDM-KS (0 in, 2 out)
#   59 System Virtual Line (Intelligo VAC (W)), Windows WDM-KS (2 in, 0 out)
#   60 Line Out 2 (Intelligo VAC (W)), Windows WDM-KS (0 in, 2 out)
#   61 Headphones (), Windows WDM-KS (0 in, 2 out)
#   62 Input (), Windows WDM-KS (2 in, 0 out)
#   63 Output (@System32\drivers\bthhfenum.sys,#4;%1 Hands-Free HF Audio%0
# ;(Kangkung 5G)), Windows WDM-KS (0 in, 1 out)
#   64 Input (@System32\drivers\bthhfenum.sys,#4;%1 Hands-Free HF Audio%0
# ;(Kangkung 5G)), Windows WDM-KS (1 in, 0 out)
#   65 Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(LE_WH-CH700N)), Windows WDM-KS (0 in, 1 out)
#   66 Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(LE_WH-CH700N)), Windows WDM-KS (1 in, 0 out)
